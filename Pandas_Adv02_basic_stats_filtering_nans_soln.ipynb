# %% [markdown]
# <a href="https://colab.research.google.com/github/KasiBaskerLaxmanan/pyalgotrading/blob/master/Pandas_Adv02_basic_stats_filtering_nans_soln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
# %matplotlib inline 
import numpy as np

# %%
### Data transformation from previous notebooks
nyc = pd.read_csv('/content/central-park-raw.csv', parse_dates=[0])
nyc.columns = [x.strip() for x in nyc.columns]
nyc.columns = [x.replace(' ', '_') for x in nyc.columns]
nyc.PrecipitationIn.replace("T", '0.001')
nyc.PrecipitationIn = pd.to_numeric(nyc.PrecipitationIn.replace("T", '0.001'))
nyc['Events'] = nyc.Events.fillna('')

# %% [markdown]
# # Basic Stats
#
# A nice feature of pandas is that you can quickly inspect data and get summary statistics.

# %%
# The describe method gives us basic stats. The result is a Data Frame
nyc.describe()
# Out:
#        Max_TemperatureF  Mean_TemperatureF  ...   CloudCover  WindDirDegrees
# count       3285.000000        3285.000000  ...  3277.000000     3285.000000
# mean          62.930898          56.042314  ...     3.231614      193.028919
# std           18.006236          16.953644  ...     2.745582      104.107605
# min           16.000000          12.000000  ...     0.000000       -1.000000
# 25%           48.000000          42.000000  ...     1.000000       78.000000
# 50%           64.000000          57.000000  ...     3.000000      236.000000
# 75%           79.000000          71.000000  ...     6.000000      279.000000
# max          104.000000          94.000000  ...     8.000000      360.000000
#
# [8 rows x 21 columns]

# %%
# Remember transpose
nyc.describe().T
# Out:
#                             count        mean  ...     75%     max
# Max_TemperatureF           3285.0   62.930898  ...   79.00  104.00
# Mean_TemperatureF          3285.0   56.042314  ...   71.00   94.00
# Min_TemperatureF           3285.0   48.701674  ...   63.00   84.00
# Max_Dew_PointF             3285.0   47.334855  ...   63.00   77.00
# MeanDew_PointF             3285.0   41.676712  ...   58.00   75.00
# Min_DewpointF              3285.0   35.374125  ...   52.00   72.00
# Max_Humidity               3285.0   78.707458  ...   93.00  100.00
# Mean_Humidity              3285.0   62.108676  ...   73.00   97.00
# Min_Humidity               3285.0   45.009132  ...   54.00   93.00
# Max_Sea_Level_PressureIn   3275.0   30.113740  ...   30.25   30.77
# Mean_Sea_Level_PressureIn  3275.0   30.006202  ...   30.15   30.69
# Min_Sea_Level_PressureIn   3275.0   29.900043  ...   30.06   30.59
# Max_VisibilityMiles        3277.0    9.939274  ...   10.00   10.00
# Mean_VisibilityMiles       3277.0    8.663717  ...   10.00   10.00
# Min_VisibilityMiles        3277.0    6.523955  ...   10.00   10.00
# Max_Wind_SpeedMPH          3245.0   14.487827  ...   17.00   99.00
# Mean_Wind_SpeedMPH         3244.0    5.826449  ...    7.00   99.00
# Max_Gust_SpeedMPH          3177.0   22.755430  ...   26.00  137.00
# PrecipitationIn            3286.0    0.148832  ...    0.05    7.57
# CloudCover                 3277.0    3.231614  ...    6.00    8.00
# WindDirDegrees             3285.0  193.028919  ...  279.00  360.00
#
# [21 rows x 8 columns]

# %%
# to view non-numeric data pass include='all'
nyc.describe(include='all').T
# Out:
#                           count unique        top  ...    50%    75%    max
# EST                        3287   3287 2007-09-10  ...    NaN    NaN    NaN
# Max_TemperatureF           3285    NaN        NaT  ...     64     79    104
# Mean_TemperatureF          3285    NaN        NaT  ...     57     71     94
# Min_TemperatureF           3285    NaN        NaT  ...     49     63     84
# Max_Dew_PointF             3285    NaN        NaT  ...     50     63     77
# MeanDew_PointF             3285    NaN        NaT  ...     43     58     75
# Min_DewpointF              3285    NaN        NaT  ...     36     52     72
# Max_Humidity               3285    NaN        NaT  ...     80     93    100
# Mean_Humidity              3285    NaN        NaT  ...     62     73     97
# Min_Humidity               3285    NaN        NaT  ...     43     54     93
# Max_Sea_Level_PressureIn   3275    NaN        NaT  ...   30.1  30.25  30.77
# Mean_Sea_Level_PressureIn  3275    NaN        NaT  ...  30.01  30.15  30.69
# Min_Sea_Level_PressureIn   3275    NaN        NaT  ...  29.91  30.06  30.59
# Max_VisibilityMiles        3277    NaN        NaT  ...     10     10     10
# Mean_VisibilityMiles       3277    NaN        NaT  ...     10     10     10
# Min_VisibilityMiles        3277    NaN        NaT  ...      9     10     10
# Max_Wind_SpeedMPH          3245    NaN        NaT  ...     14     17     99
# Mean_Wind_SpeedMPH         3244    NaN        NaT  ...      5      7     99
# Max_Gust_SpeedMPH          3177    NaN        NaT  ...     22     26    137
# PrecipitationIn            3286    NaN        NaT  ...      0   0.05   7.57
# CloudCover                 3277    NaN        NaT  ...      3      6      8
# Events                     3287      9        NaT  ...    NaN    NaN    NaN
# WindDirDegrees             3285    NaN        NaT  ...    236    279    360
#
# [23 rows x 13 columns]

# %%
# Various aggregation methods (max, mean, median, min, mad, skew, kurtosis, autocorr,
#   nunique, sem, std, var)
# and properties (hasnans, is_monotonic, is_unique)
nyc.Max_Humidity.max()
# Out:
# 100.0

# %%
nyc.Max_Humidity.quantile(.2)
# Out:
# 64.0

# %%
nyc.Max_Humidity.quantile([.2,.3])
# Out:
# 0.2    64.0
# 0.3    70.0
# Name: Max_Humidity, dtype: float64

# %%
nyc.Max_Humidity.min()
# Out:
# 28.0

# %%
nyc.Mean_Humidity.corr(nyc.Mean_TemperatureF)
# Out:
# 0.255606399799407

# %% [markdown]
# ## Basic Stats Assignment
#
# * *Describe* the data
# * Choose a column
#   * Print out the max, min, and mean
# * Correlate (``corr``) the temperature column with the date column

# %%
# %timeit
# Data transformation from previous notebook
# col names in tao-all2.col from website
names = '''obs
year
month
day
date
latitude
longitude
zon.winds
mer.winds
humidity
air temp.
s.s.temp.'''.split('\n')

nino = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/el_nino-mld/tao-all2.dat.gz', sep=' ', names=names, na_values='.', 
                   parse_dates=[[1,2,3]])
nino.columns = [x.replace('.', '_').replace(' ', '_') for x in nino.columns]
nino['air_temp_F'] = nino.air_temp_ * 9/5 + 32
wind_cols = [x for x in nino.columns if x.endswith('winds')]
for c in wind_cols:
    nino['{}_mph'.format(c)] = nino[c] * 2.237
pd.to_datetime(nino.date, format='%y%m%d')
nino = nino.drop('obs', axis=1)
nino.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178080 entries, 0 to 178079
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year_month_day  178080 non-null  datetime64[ns]
#  1   date            178080 non-null  int64
#  2   latitude        178080 non-null  float64
#  3   longitude       178080 non-null  float64
#  4   zon_winds       152917 non-null  float64
#  5   mer_winds       152918 non-null  float64
#  6   humidity        112319 non-null  float64
#  7   air_temp_       159843 non-null  float64
#  8   s_s_temp_       161073 non-null  float64
#  9   air_temp_F      159843 non-null  float64
#  10  zon_winds_mph   152917 non-null  float64
#  11  mer_winds_mph   152918 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1)
# memory usage: 16.3 MB

# %%
nino.describe().T
# Out:
#                   count           mean  ...          75%          max
# date           178080.0  933689.455374  ...  960617.0000  980623.0000
# latitude       178080.0       0.473626  ...       4.9800       9.0500
# longitude      178080.0     -54.025233  ...     147.0100     171.0800
# zon_winds      152917.0      -3.304772  ...      -1.4000      14.3000
# mer_winds      152918.0       0.249762  ...       2.3000      13.0000
# humidity       112319.0      81.236525  ...      84.8000      99.9000
# air_temp_      159843.0      26.887567  ...      28.1800      31.6600
# s_s_temp_      161073.0      27.715309  ...      29.2300      31.2600
# air_temp_F     159843.0      80.397620  ...      82.7240      88.9880
# zon_winds_mph  152917.0      -7.392775  ...      -3.1318      31.9891
# mer_winds_mph  152918.0       0.558718  ...       5.1451      29.0810
#
# [11 rows x 8 columns]

# %%
nino.humidity.agg([np.min, np.max, np.mean])
# Out:
# amin    45.400000
# amax    99.900000
# mean    81.236525
# Name: humidity, dtype: float64

# %%
nino.humidity.agg(['min', 'max', 'mean'])
# Out:
# min     45.400000
# max     99.900000
# mean    81.236525
# Name: humidity, dtype: float64

# %%
nino.humidity.apply(['min', 'max', 'mean'])
# Out:
# min     45.400000
# max     99.900000
# mean    81.236525
# Name: humidity, dtype: float64

# %%
nino.date.corr(nino.air_temp_)
# Out:
# 0.26539437797168147

# %%
# Bonus - Visualization of correlation
nino.set_index('year_month_day').air_temp_.plot(figsize=(14,10), alpha=.5) #plot(kind='scatter', x='year_month_day', y='air_temp_')

# %%
# Resample to see more clear
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliasescv
# (.resample returns a groupby so we need to call median on the air_temp_ column)
(nino
 .set_index('year_month_day')
 .resample('W')
 .air_temp_
 .median()
 .plot(figsize=(14,10), alpha=.5) # Alpha lets you see thru the scatter or plot
 ) 
#

# %%
# Resample to see more clear
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliasescv
# (.resample returns a groupby so we need to call median on the air_temp_ column)
(nino
 .set_index('year_month_day')
 .resample('M')
 .air_temp_
 .agg(['max', 'median', 'min'])
 .plot(figsize=(14,10), alpha=.5)
 ) #

# %% [markdown]
# ## Basic Stats Extra
# * use the ``scatter_matrix`` function in ``pandas.plotting`` to create a correlation matrix (note this might take tens of seconds to run)

# %%
pd.plotting.scatter_matrix(nino)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112c9ad68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112f5af60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112fbff98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11301aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11307fda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11307fdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1171c8940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118593748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1185fa898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118654588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186ba9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11870f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11877b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118797048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11883c710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1188a1a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1188fa358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118962668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1189be1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a25128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a7fb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ae6eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112c93780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b7e198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118bcbe48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c3f470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c5d390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d001d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d664e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118db9dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118e28128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118e7cc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ee3ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118f44630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118faa978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119006cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119072240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1190c7b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119133160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119186978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1191f0e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11920c240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1192b1cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11956ffd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1195c9908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119630c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119688780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119f1b6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119f7d160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119fe24a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a390828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a3f8d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118fc2a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a49c470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a43d6a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a557ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a574a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a61a6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a7e19e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a83c358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad15668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad6e1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11afa0128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11affab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b062eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b0c3278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b3e0780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b43d0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b4a26a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b669eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c5673c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c586588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c628240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c691550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c6e2e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c750198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7a5cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c80ac18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c86b6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8d59e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c92ed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c99e2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c9f0ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca5e1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11caac9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cb17eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cb36eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cbd9d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11cc49080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cc9b978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ccffc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cd2b898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cd9e780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cdfb828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce61c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cebbef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf2a438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf7dd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cfea358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d039b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0ac080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0b4860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d166eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1d4208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d225b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d28ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d2e9978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3518d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d3b3358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4186a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d474a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4d9f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d535860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d59be48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d5f86a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d65cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d678208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d71e9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d785cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d7e0630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d847940>]], dtype=object)

# %% [markdown]
# # Plotting
#
# Pandas has built-in integration with Matplotlib. Other libraries such as Seaborn also support plotting DataFrames and Series. This is not an in depth intro to Matplotlib, but their website and gallery are great for finding more information

# %%
# histograms are a quick way to visualize the distribution
nyc.Mean_Humidity.hist()

# %%
# add in figsize=(width,height) to boost size
nyc.Mean_Humidity.hist(figsize=(14, 10))

# %%
# If we use the .plot method we can add title and other attributes
nyc.Mean_Humidity.plot(kind='hist', title='Avg Humidity', figsize=(14, 10))

# %%
nyc.plot(x='EST', y='Mean_Humidity')

# %%
nyc.plot(x='EST', y='Mean_Humidity', figsize=(12, 8) )

# %%
# Can resample columns, since our index is a date we can use *Offset Aliases*
# see http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases
nyc.set_index('EST').Mean_Humidity.resample('M').mean().plot(figsize=(10, 6))

# %%
# Can resample columns, since our index is a date we can use *Offset Aliases*
# see http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases
nyc.set_index('EST').Mean_Humidity.resample('2W').mean().plot(figsize=(10, 6))

# %%
# Plot all the things (may be useful or just art)
nyc.set_index('EST').plot(figsize=(12,8))

# %%
nyc.plot(x='Max_TemperatureF', y='Max_Humidity', kind='scatter', alpha=.5, 
        figsize=(10, 8))

# %%
nyc.Max_TemperatureF.corr(nyc.Max_Humidity)
# Out:
# 0.27391561202292231

# %% [markdown]
# ## Plotting Assignment
# * Plot a histogram of air temp
# * Plot a scatter plot of latitude and longitude

# %%
nino['air_temp_'].hist(figsize=(10,8))

# %%
nino['air_temp_'].plot(kind='hist', title='Air Temp', figsize=(10,8))

# %%
nino.plot(x='longitude', y='latitude', kind='scatter', figsize=(10, 8), alpha=.1,s=2)
#

# %%
# try to see if we can size by air temp
nino.plot(x='longitude', y='latitude', kind='scatter', s='ait_temp_')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-537a61db48bb> in <module>()
#       1 # try to see if we can size by air temp
# ----> 2 nino.plot(x='longitude', y='latitude', kind='scatter', s='ait_temp_')
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#     973             label=label,
#     974             cmap=cmap,
# --> 975             **self.kwds,
#     976         )
#     977         if cb:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4427                 offsets=offsets,
#    4428                 transOffset=kwargs.pop('transform', self.transData),
# -> 4429                 alpha=alpha
#    4430                 )
#    4431         collection.set_transform(mtransforms.IdentityTransform())
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     912         Collection.__init__(self, **kwargs)
#     913         self.set_paths(paths)
# --> 914         self.set_sizes(sizes)
#     915         self.stale = True
#     916
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py in set_sizes(self, sizes, dpi)
#     884             self._sizes = np.asarray(sizes)
#     885             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 886             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     887             self._transforms[:, 0, 0] = scale
#     888             self._transforms[:, 1, 1] = scale
#
# TypeError: ufunc 'sqrt' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
nino['year'] = nino.year_month_day.dt.year

# %%
# whoops, need to provide an array of values
# we will also color by year
nino.plot(x='longitude', y='latitude', kind='scatter', 
          s=nino['air_temp_'].values*10, 
          c='year', 
          figsize=(10,8),
          colorbar=True)

# %% [markdown]
# # Filtering

# %%
# When we apply a conditional operator to a series we get back a series of True/False values
# We call this a "mask", which we can use to filter (similar to Photoshop)
# all EST in 2000's
m2000 = nyc.EST.dt.year >= 2000

# below 2010
lt2010 = nyc.EST.dt.year < 2010

# %%
# The "and" operation looks at whether the operands are truthy or falsey
# This is a case where normal Python syntax doesn't work
nyc[m2000 and lt2010]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-1e11f63cab38> in <module>()
#       1 # The "and" operation looks at whether the operands are truthy or falsey
#       2 # This is a case where normal Python syntax doesn't work
# ----> 3 nyc[m2000 and lt2010]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# & does bitwise comparisons - which is what we want
nyc[m2000 & lt2010]
# Out:
#             EST  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 0    2006-01-01              42.0               37.0              32.0
# 1    2006-01-02              48.0               44.0              39.0
# 2    2006-01-03              40.0               37.0              33.0
# 3    2006-01-04              38.0               34.0              29.0
# 4    2006-01-05              50.0               44.0              37.0
# 5    2006-01-06              43.0               37.0              30.0
# 6    2006-01-07              35.0               30.0              25.0
# 7    2006-01-08              46.0               40.0              34.0
# 8    2006-01-09              60.0               52.0              43.0
# 9    2006-01-10              49.0               45.0              41.0
# 10   2006-01-11              52.0               47.0              42.0
# 11   2006-01-12              57.0               51.0              45.0
# 12   2006-01-13              54.0               49.0              43.0
# 13   2006-01-14              57.0               44.0              31.0
# 14   2006-01-15              32.0               24.0              16.0
# 15   2006-01-16              32.0               24.0              16.0
# 16   2006-01-17              44.0               35.0              26.0
# 17   2006-01-18              58.0               47.0              36.0
# 18   2006-01-19              47.0               41.0              34.0
# 19   2006-01-20              61.0               52.0              42.0
# 20   2006-01-21              63.0               51.0              38.0
# 21   2006-01-22              43.0               38.0              33.0
# 22   2006-01-23              40.0               38.0              35.0
# 23   2006-01-24              46.0               41.0              35.0
# 24   2006-01-25              42.0               38.0              34.0
# 25   2006-01-26              35.0               31.0              26.0
# 26   2006-01-27              43.0               34.0              24.0
# 27   2006-01-28              58.0               48.0              37.0
# 28   2006-01-29              53.0               49.0              44.0
# 29   2006-01-30              64.0               53.0              41.0
# ...         ...               ...                ...               ...
# 1431 2009-12-02              56.0               49.0              41.0
# 1432 2009-12-03              66.0               59.0              51.0
# 1433 2009-12-04              52.0               48.0              44.0
# 1434 2009-12-05              45.0               39.0              33.0
# 1435 2009-12-06              38.0               36.0              33.0
# 1436 2009-12-07              39.0               36.0              32.0
# 1437 2009-12-08              44.0               39.0              34.0
# 1455       Rain            72.0
# 1456       Rain           224.0
# 1457                      259.0
# 1458                      289.0
# 1459                      249.0
# 1460   Fog-Snow           247.0
#
# [1461 rows x 23 columns]

# %%
# beware if you embed the operations, the bitwise operator binds more tightly to the integers
nyc[(nyc.EST.dt.year >= 2000) & (nyc.EST.dt.year < 2010)]
# Out:
#             EST  Max_TemperatureF  ...    Events  WindDirDegrees
# 0    2006-01-01              42.0  ...                     276.0
# 1    2006-01-02              48.0  ...      Rain            76.0
# 2    2006-01-03              40.0  ...      Rain            39.0
# 3    2006-01-04              38.0  ...                      70.0
# 4    2006-01-05              50.0  ...      Rain           251.0
# ...         ...               ...  ...       ...             ...
# 1456 2009-12-27              55.0  ...      Rain           224.0
# 1457 2009-12-28              43.0  ...                     259.0
# 1458 2009-12-29              31.0  ...                     289.0
# 1459 2009-12-30              32.0  ...                     249.0
# 1460 2009-12-31              35.0  ...  Fog-Snow           247.0
#
# [1461 rows x 23 columns]

# %%
# beware if you embed the operations, the bitwise operator binds more tightly to the integers
nyc[(nyc.EST.dt.year >= 2000) & (nyc.EST.dt.year < 2010)]
# Out:
#             EST  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 0    2006-01-01              42.0               37.0              32.0
# 1    2006-01-02              48.0               44.0              39.0
# 2    2006-01-03              40.0               37.0              33.0
# 3    2006-01-04              38.0               34.0              29.0
# 4    2006-01-05              50.0               44.0              37.0
# 5    2006-01-06              43.0               37.0              30.0
# 6    2006-01-07              35.0               30.0              25.0
# 7    2006-01-08              46.0               40.0              34.0
# 8    2006-01-09              60.0               52.0              43.0
# 9    2006-01-10              49.0               45.0              41.0
# 10   2006-01-11              52.0               47.0              42.0
# 11   2006-01-12              57.0               51.0              45.0
# 12   2006-01-13              54.0               49.0              43.0
# 13   2006-01-14              57.0               44.0              31.0
# 14   2006-01-15              32.0               24.0              16.0
# 15   2006-01-16              32.0               24.0              16.0
# 16   2006-01-17              44.0               35.0              26.0
# 17   2006-01-18              58.0               47.0              36.0
# 18   2006-01-19              47.0               41.0              34.0
# 19   2006-01-20              61.0               52.0              42.0
# 20   2006-01-21              63.0               51.0              38.0
# 21   2006-01-22              43.0               38.0              33.0
# 22   2006-01-23              40.0               38.0              35.0
# 23   2006-01-24              46.0               41.0              35.0
# 24   2006-01-25              42.0               38.0              34.0
# 25   2006-01-26              35.0               31.0              26.0
# 26   2006-01-27              43.0               34.0              24.0
# 27   2006-01-28              58.0               48.0              37.0
# 28   2006-01-29              53.0               49.0              44.0
# 29   2006-01-30              64.0               53.0              41.0
# ...         ...               ...                ...               ...
# 1431 2009-12-02              56.0               49.0              41.0
# 1432 2009-12-03              66.0               59.0              51.0
# 1433 2009-12-04              52.0               48.0              44.0
# 1434 2009-12-05              45.0               39.0              33.0
# 1435 2009-12-06              38.0               36.0              33.0
# 1436 2009-12-07              39.0               36.0              32.0
# 1437 2009-12-08              44.0               39.0              34.0
# 1438 2009-12-09              53.0               43.0              33.0
# 1439 2009-12-10              46.0               37.0              27.0
# 1440 2009-12-11              29.0               25.0              21.0
# 1441 2009-12-12              37.0               31.0              25.0
# 1442 2009-12-13              52.0               43.0              34.0
# 1443 2009-12-14              46.0               43.0              40.0
# 1444 2009-12-15              52.0               47.0              42.0
# 1445 2009-12-16              42.0               35.0              28.0
# 26                   8.0               22.0            0.000         0.0
# 27                   6.0               21.0            0.000         0.0
# 28                   5.0               20.0            0.140         5.0
# 29                   8.0               28.0            0.010         4.0
# ...                  ...                ...              ...         ...
# 1431                 5.0               25.0            0.450         4.0
# 1432                11.0               35.0            0.730         6.0
# 1433                 5.0               15.0            0.000         0.0
# 1434                 7.0               24.0            0.640         7.0
# 1435                 7.0               23.0            0.000         1.0
# 1436                 5.0               18.0            0.000         2.0
# 1437                 7.0               20.0            0.001         1.0
# 1438                 8.0               30.0            1.480         7.0
# 1439                12.0               32.0            0.000         3.0
# 1440                13.0               36.0            0.000         2.0
# 1441                 8.0               23.0            0.000         0.0
# 1442                 6.0               22.0            0.950         6.0
# 1443                 5.0               23.0            0.000         4.0
# 1444                 7.0               26.0            0.000         6.0
# 1445                11.0               25.0            0.000         1.0
# 1446                12.0               32.0            0.000         2.0
# 1447                 5.0               17.0            0.000         0.0
# 1448                11.0               31.0            0.610         8.0
# 1449                10.0               33.0            0.130         6.0
# 1450                11.0               35.0            0.000         1.0
# 1451                 9.0               29.0            0.000         0.0
# 1452                10.0               25.0            0.000         1.0
# 1453                 6.0               26.0            0.000         1.0
# 1454                 9.0               30.0            0.240         8.0
# 1455                12.0               30.0            1.480         8.0
# 1456                 8.0               29.0            0.330         5.0
# 1457                 9.0               29.0            0.000         4.0
# 1458                14.0               40.0            0.001         1.0
# 1459                 6.0               22.0            0.000         1.0
# 1460                 4.0               17.0            0.230         8.0
#
#          Events  WindDirDegrees
# 0                         276.0
# 1          Rain            76.0
# 2          Rain            39.0
# 3                          70.0
# 4          Rain           251.0
# 5                         317.0
# 6                         267.0
# 7                         192.0
# 8                         249.0
# 9                         261.0
# 10         Rain            71.0
# 11                        246.0
# 12                        171.0
# 13         Rain           158.0
# 14     Fog-Snow           298.0
# 15                        279.0
# 16         Rain            67.0
# 17         Rain           217.0
# 18                        244.0
# 19                        233.0
# 20                        263.0
# 21                         49.0
# 22    Rain-Snow            51.0
# 23                        185.0
# 24                        266.0
# 25                        292.0
# 26                        274.0
# 27                        243.0
# 28         Rain           169.0
# 29                         64.0
# ...         ...             ...
# 1431       Rain           142.0
# 1432       Rain           204.0
# 1433                      273.0
# 1434  Rain-Snow            11.0
# 1435                      281.0
# 1436                      242.0
# 1437                      296.0
# 1438  Rain-Snow            82.0
# 1439                      267.0
# 1440                      267.0
# 1441                      261.0
# 1442       Rain           207.0
# 1443                      218.0
# 1444                      260.0
# 1445                      286.0
# 1446                      290.0
# 1447                       10.0
# 1448   Fog-Snow            21.0
# 1449   Fog-Snow           299.0
# 1450                      287.0
# 1451                      284.0
# 1452                      281.0
# 1453                        5.0
# 1454       Rain            61.0
# 1455       Rain            72.0
# 1456       Rain           224.0
# 1457                      259.0
# 1458                      289.0
# 1459                      249.0
# 1460   Fog-Snow           247.0
#
# [1461 rows x 23 columns]

# %%
m_dec = nyc.EST.dt.month == 12
nyc[m_dec]
# Out:
#             EST  Max_TemperatureF  ...  Events  WindDirDegrees
# 334  2006-12-01              70.0  ...    Rain           196.0
# 335  2006-12-02              49.0  ...                   281.0
# 336  2006-12-03              46.0  ...                   247.0
# 337  2006-12-04              41.0  ...                   291.0
# 338  2006-12-05              37.0  ...                   275.0
# ...         ...               ...  ...     ...             ...
# 3282 2014-12-27              55.0  ...                   257.0
# 3283 2014-12-28              54.0  ...    Rain           264.0
# 3284 2014-12-29              44.0  ...                   308.0
# 3285 2014-12-30              34.0  ...                     5.0
# 3286 2014-12-31              32.0  ...                   275.0
#
# [279 rows x 23 columns]

# %%
# Can use loc to filter out based on index value, also takes a boolean index
# In fact, you should use .loc instead as a matter of habit (you won't see warnings)
nyc.loc[m_dec]
# Out:
#             EST  Max_TemperatureF  ...  Events  WindDirDegrees
# 334  2006-12-01              70.0  ...    Rain           196.0
# 335  2006-12-02              49.0  ...                   281.0
# 336  2006-12-03              46.0  ...                   247.0
# 337  2006-12-04              41.0  ...                   291.0
# 338  2006-12-05              37.0  ...                   275.0
# ...         ...               ...  ...     ...             ...
# 3282 2014-12-27              55.0  ...                   257.0
# 3283 2014-12-28              54.0  ...    Rain           264.0
# 3284 2014-12-29              44.0  ...                   308.0
# 3285 2014-12-30              34.0  ...                     5.0
# 3286 2014-12-31              32.0  ...                   275.0
#
# [279 rows x 23 columns]

# %%
# Can use loc to filter out based on index value, also takes a boolean index
# 2nd option in index op is column names (: to include everything)
nyc.loc[m_dec, [x for x in nyc.columns if 'Max' in x]]
# Out:
#       Max_TemperatureF  Max_Dew_PointF  ...  Max_Wind_SpeedMPH  Max_Gust_SpeedMPH
# 334               70.0            63.0  ...               23.0               44.0
# 335               49.0            28.0  ...               21.0               37.0
# 336               46.0            29.0  ...               13.0               20.0
# 337               41.0            25.0  ...               18.0               32.0
# 338               37.0            18.0  ...               17.0               26.0
# ...                ...             ...  ...                ...                ...
# 3282              55.0            35.0  ...               14.0               25.0
# 3283              54.0            43.0  ...               15.0               22.0
# 3284              44.0            25.0  ...               15.0               25.0
# 3285              34.0            17.0  ...               10.0               17.0
# 3286              32.0            12.0  ...               14.0               21.0
#
# [279 rows x 7 columns]

# %%
# loc note:
# can use set_index and sort_index to do quick lookups (if you sort you get quick lookups)
nyc.set_index('Events').sort_index().head()
# Out:
#               EST  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# Events
#        2006-01-01              42.0               37.0              32.0
#        2011-04-29              69.0               62.0              54.0
#        2011-04-30              67.0               59.0              50.0
#        2011-05-01              69.0               60.0              50.0
#        2011-05-02              63.0               57.0              50.0
#
#         Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  \
# Events
#                   32.0            30.0           28.0          85.0
#                   44.0            41.0           38.0          62.0
#                   41.0            37.0           33.0          64.0
#                   42.0            39.0           35.0          74.0
#                   50.0            45.0           39.0          83.0
#
#         Mean_Humidity  Min_Humidity       ...        Min_Sea_Level_PressureIn  \
# Events                                    ...
#                  74.0          62.0       ...                           29.83
#                  49.0          35.0       ...                           29.68
#                  48.0          31.0       ...                           29.92
#                  53.0          32.0       ...                           30.23
#                  72.0          60.0       ...                           30.13
#
#         Max_VisibilityMiles  Mean_VisibilityMiles  Min_VisibilityMiles  \
# Events
#                        10.0                  10.0                  8.0
#                        10.0                  10.0                 10.0
#                        10.0                  10.0                 10.0
#                        10.0                  10.0                 10.0
#                        10.0                  10.0                 10.0
#
#         Max_Wind_SpeedMPH  Mean_Wind_SpeedMPH  Max_Gust_SpeedMPH  \
# Events
#                       9.0                 3.0               10.0
#                      16.0                 7.0               23.0
#                      15.0                 5.0               22.0
#                      13.0                 5.0               18.0
#                      10.0                 5.0               16.0
#
#         PrecipitationIn  CloudCover  WindDirDegrees
# Events
#                     0.0         8.0           276.0
#                     0.0         4.0           262.0
#                     0.0         4.0            17.0
#                     0.0         0.0           133.0
#                     0.0         5.0           131.0
#
# [5 rows x 22 columns]

# %%
(nyc
 .set_index('Events')
 .sort_index()
 .loc['Fog':'Main']
)
# Out:
#                 EST  Max_TemperatureF  ...  CloudCover  WindDirDegrees
# Events                                 ...
# Fog      2013-01-13              50.0  ...         8.0           160.0
# Fog      2006-05-27              82.0  ...         3.0            19.0
# Fog      2009-03-02              28.0  ...         8.0           352.0
# Fog      2011-03-22              50.0  ...         6.0           301.0
# Fog      2011-05-24              81.0  ...         5.0           253.0
# ...             ...               ...  ...         ...             ...
# Fog-Snow 2008-02-29              35.0  ...         4.0           171.0
# Fog-Snow 2006-02-12              28.0  ...         7.0           339.0
# Fog-Snow 2009-03-01              36.0  ...         8.0            33.0
# Fog-Snow 2006-02-11              36.0  ...         8.0            53.0
# Fog-Snow 2008-02-22              34.0  ...         8.0           103.0
#
# [265 rows x 22 columns]

# %%
# Can use iloc to filter out based on index location (or position)
# 2nd option in index op is column indices
nyc.iloc[5:10, [2, 5, -2]]
# Out:
#    Mean_TemperatureF  MeanDew_PointF Events
# 5               37.0            24.0
# 6               30.0            14.0
# 7               40.0            25.0
# 8               52.0            36.0
# 9               45.0            28.0

# %%
# Can use iloc to filter out based on index location
# 2nd option in index op is column indices
nyc.iloc[:, [2, 5, -2]]
# Out:
#       Mean_TemperatureF  MeanDew_PointF     Events
# 0                  37.0            30.0
# 1                  44.0            34.0       Rain
# 2                  37.0            33.0       Rain
# 3                  34.0            26.0
# 4                  44.0            35.0       Rain
# 5                  37.0            24.0
# 6                  30.0            14.0
# 7                  40.0            25.0
# 8                  52.0            36.0
# 9                  45.0            28.0
# 10                 47.0            42.0       Rain
# 11                 51.0            36.0
# 12                 49.0            43.0
# 13                 44.0            49.0       Rain
# 14                 24.0            12.0   Fog-Snow
# 15                 24.0             5.0
# 16                 35.0            21.0       Rain
# 17                 47.0            43.0       Rain
# 18                 41.0            21.0
# 19                 52.0            32.0
# 20                 51.0            32.0
# 21                 38.0            16.0
# 22                 38.0            35.0  Rain-Snow
# 23                 41.0            26.0
# 24                 38.0            26.0
# 25                 31.0            14.0
# 26                 34.0            10.0
# 27                 48.0            20.0
# 28                 49.0            39.0       Rain
# 29                 53.0            43.0
# ...                 ...             ...        ...
# 3257               39.0            30.0       Rain
# 3258               44.0            38.0       Rain
# 3259               41.0            21.0
# 3260               39.0            33.0       Rain
# 3261               45.0            42.0       Rain
# 3262               36.0            18.0       Rain
# 3263               31.0            17.0
# 3264               39.0            36.0       Rain
# 3265               36.0            31.0  Rain-Snow
# 3266               35.0            23.0       Snow
# 3267               35.0            21.0
# 3268               39.0            25.0
# 3269               42.0            29.0
# 3270               43.0            29.0
# 3271               44.0            39.0       Rain
# 3272               48.0            39.0       Rain
# 3273               40.0            23.0
# 3274               35.0            21.0
# 3275               32.0            19.0
# 3276               34.0            25.0       Snow
# 3277               40.0            35.0       Rain
# 3278               45.0            42.0       Rain
# 3279               51.0            47.0       Rain
# 3280               53.0            40.0       Rain
# 3281               45.0            28.0
# 3282               50.0            31.0
# 3283               49.0            37.0       Rain
# 3284               39.0            19.0
# 3285               31.0            13.0
# 3286               30.0             8.0
#
# [3287 rows x 3 columns]

# %%
nyc.EST.describe()
# Out:
# count                    3287
# unique                   3287
# top       2007-09-10 00:00:00
# freq                        1
# first     2006-01-01 00:00:00
# last      2014-12-31 00:00:00
# Name: EST, dtype: object

# %% [markdown]
# ## Filtering Assignment
# * Create a mask, ``m80``, that all years >= 1980 and < 1990
# * Create a mask, ``m90``, that all years >= 1990 and < 2000
# * Create a mask, ``lon120``, that has all longitudes > 120
# * Create a mask, ``lat0``, that has latitudes > -2 and < 2
# * Create a dataframe, ``df80``, that has only those values in ``m80`` and ``lon120`` and ``lat0``
# * Create a dataframe, ``df90``, that has only those values in ``m90`` and ``lon120`` and ``lat0``

# %%
m80 = (nino.year >= 1980) & (nino.year < 1990)
m90 = (nino.year >= 1990) & (nino.year < 2000)
lon120 = nino.longitude > 120
lat0 = (nino.latitude > -2) & (nino.latitude < 2)
df80 = nino[m80 & lon120 & lat0]
df90 = nino[m90 & lon120 & lat0]

# %%
df80
# Out:
#       year_month_day    obs    date  latitude  longitude  zon.winds  \
# 22471     1986-04-21  22472  860421      0.05     164.99       -6.9
# 22472     1986-04-22  22473  860422      0.05     164.98       -6.2
# 22473     1986-04-23  22474  860423      0.05     164.99       -4.1
# 22474     1986-04-24  22475  860424      0.05     164.99       -4.7
# 22475     1986-04-25  22476  860425      0.04     164.99       -4.4
# 22476     1986-04-26  22477  860426      0.05     165.00       -5.9
# 22477     1986-04-27  22478  860427      0.05     164.99       -5.4
# 22478     1986-04-28  22479  860428      0.05     165.00       -3.6
# 22479     1986-04-29  22480  860429      0.04     164.98       -2.0
# 22480     1986-04-30  22481  860430      0.05     164.99       -3.5
# 22481     1986-05-01  22482  860501      0.05     164.99       -5.7
# 22482     1986-05-02  22483  860502      0.04     164.99       -7.1
# 22483     1986-05-03  22484  860503      0.04     165.01       -5.1
# 22484     1986-05-04  22485  860504      0.04     165.01       -5.1
# 22485     1986-05-05  22486  860505      0.04     165.00       -5.2
# 22486     1986-05-06  22487  860506      0.05     165.00       -4.1
# 22487     1986-05-07  22488  860507      0.04     164.98       -1.7
# 22488     1986-05-08  22489  860508      0.04     165.00        0.4
# 22489     1986-05-09  22490  860509      0.05     165.00        3.7
# 22479       -2.5       NaN      28.29        NaN  1986
# 22480        0.5       NaN      28.65        NaN  1986
# 22481        1.4       NaN      28.61        NaN  1986
# 22482       -1.2       NaN      28.70        NaN  1986
# 22483       -1.3       NaN      28.60        NaN  1986
# 22484       -1.5       NaN      28.44        NaN  1986
# 22485        1.7       NaN      28.48        NaN  1986
# 22486        2.8       NaN      28.37        NaN  1986
# 22487       -0.6       NaN      28.37        NaN  1986
# 22488       -0.7       NaN      28.21        NaN  1986
# 22489        1.2       NaN      28.74        NaN  1986
# 22490        1.6       NaN      28.83        NaN  1986
# 22491        0.5       NaN      28.75        NaN  1986
# 22492       -3.4       NaN      28.35        NaN  1986
# 22493       -3.7       NaN      27.39        NaN  1986
# 22494       -7.7       NaN      28.47        NaN  1986
# 22495       -3.3       NaN      27.98        NaN  1986
# 22496       -2.5       NaN      27.09        NaN  1986
# 22497       -0.8       NaN      28.59        NaN  1986
# 22498       -0.9       NaN      28.67        NaN  1986
# 22499       -2.9       NaN      28.89        NaN  1986
# 22500       -4.9       NaN      28.99        NaN  1986
# ...          ...       ...        ...        ...   ...
# 83783        2.0       NaN      27.84      28.01  1988
# 83784       -2.5       NaN      27.56      28.21  1988
# 83785       -3.1       NaN      27.36      28.26  1988
# 83786       -1.4       NaN      27.50      28.43  1988
# 83787        0.3       NaN      27.58      28.83  1988
# 83788        0.1       NaN      28.03      29.60  1988
# 83795       -1.9       NaN      27.72      28.87  1988
# 83797        0.9       NaN      28.20      28.82  1988
# 83798       -4.1       NaN      27.92      28.85  1988
# 83799       -3.8       NaN      27.74      28.95  1988
# 83802       -1.3       NaN      27.88      29.13  1988
# 83803       -1.8       NaN      27.64      28.90  1988
# 83823       -5.6       NaN      27.56      28.26  1988
# 83824       -4.7       NaN      27.51      28.09  1988
# 83825       -2.6       NaN      27.72      28.17  1988
# 83826       -1.1       NaN      28.04      28.33  1988
# 83827       -0.2       NaN      27.97      28.57  1988
# 83837       -3.5       NaN      27.45      28.03  1988
# 83838       -4.4       NaN      27.35      28.12  1988
# 83839       -4.1       NaN      27.43      28.39  1988
# 83840       -2.7       NaN      27.67      28.82  1988
# 83841       -4.2       NaN      27.86      28.78  1988
# 83842       -3.6       NaN      27.83      28.88  1988
# 83843       -2.8       NaN      27.63      28.79  1988
# 83844       -3.3       NaN      27.52      28.78  1988
# 83845       -1.3       NaN      27.52      28.83  1988
# 83846       -1.7       NaN      27.62      28.73  1988
# 83853       -3.3       NaN      26.93      27.61  1988
# 83854       -5.3       NaN      26.97      27.54  1988
# 83858       -2.2       NaN      27.06      27.70  1988
#
# [3334 rows x 11 columns]

# %%
df90
# Out:
#       year_month_day    obs    date  latitude  longitude  zon.winds  \
# 15098     1992-04-26  15099  920426      0.03     143.03        0.7
# 15099     1992-04-27  15100  920427      0.03     143.04       -0.6
# 15100     1992-04-28  15101  920428      0.02     143.02       -2.1
# 15101     1992-04-29  15102  920429      0.02     143.03       -1.1
# 15102     1992-04-30  15103  920430      0.02     143.03       -0.4
# 15103     1992-05-01  15104  920501      0.02     143.03       -0.4
# 87040       -0.3      78.0      28.67        NaN  1998
# 87041       -2.3      82.5      28.48        NaN  1998
# 87042       -2.9      79.6      28.55        NaN  1998
# 87043       -2.7      80.1      28.49        NaN  1998
# 87044        1.1      80.9      28.26        NaN  1998
# 87045        1.7      80.9      28.45        NaN  1998
# 87046       -2.3      83.3      28.18        NaN  1998
#
# [15738 rows x 11 columns]

# %% [markdown]
# ## Filtering Bonus Assignment
# * Create a mask, ``m80_2``, that uses a function to filter years >= 1980 and < 1990
# * Make sure that ``m80`` is created using operations
# * Use the ``%%time`` *cell magic* to determine which is faster to calculate, ``m80`` or ``m80_2``

# %%
# %%time
def lt1990(v):
    return v >= 1980 and v < 1990
m80_2 = nino.year.apply(lt1990)
nino[m80_2]
# Out:
# CPU times: user 53.6 ms, sys: 6.5 ms, total: 60.1 ms
# Wall time: 58.9 ms

# %%
# %%time
m80 = (nino.year >= 1980) & (nino.year < 1990)
nino[m80]
# Out:
# CPU times: user 4.78 ms, sys: 1.04 ms, total: 5.82 ms
# Wall time: 5.58 ms

# %% [markdown]
# # Dealing with NaN

# %%
nyc.isna().any(axis=0)
# Out:
# EST                          False
# Max_TemperatureF              True
# Mean_TemperatureF             True
# Min_TemperatureF              True
# Max_Dew_PointF                True
# MeanDew_PointF                True
# Min_DewpointF                 True
# Max_Humidity                  True
# Mean_Humidity                 True
# Min_Humidity                  True
# Max_Sea_Level_PressureIn      True
# Mean_Sea_Level_PressureIn     True
# Min_Sea_Level_PressureIn      True
# Max_VisibilityMiles           True
# Mean_VisibilityMiles          True
# Min_VisibilityMiles           True
# Max_Wind_SpeedMPH             True
# Mean_Wind_SpeedMPH            True
# Max_Gust_SpeedMPH             True
# PrecipitationIn               True
# CloudCover                    True
# Events                       False
# WindDirDegrees                True
# dtype: bool

# %%
# find rows that have null data
# fish create a mask
nyc.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3282    False
# 3283    False
# 3284    False
# 3285    False
# 3286    False
# Length: 3287, dtype: bool

# %%
nyc[nyc.isnull().any(axis=1)]
# Out:
#             EST  Max_TemperatureF  ...  Events  WindDirDegrees
# 86   2006-03-28              55.0  ...                    93.0
# 87   2006-03-29              63.0  ...                   129.0
# 103  2006-04-14              66.0  ...    Rain           137.0
# 116  2006-04-27              73.0  ...                   299.0
# 123  2006-05-04              82.0  ...                   215.0
# ...         ...               ...  ...     ...             ...
# 2945 2014-01-24              19.0  ...                    -1.0
# 2956 2014-02-04              35.0  ...                    74.0
# 3049 2014-05-08              59.0  ...    Rain            81.0
# 3120 2014-07-18              81.0  ...                    44.0
# 3121 2014-07-19              76.0  ...                    60.0
#
# [113 rows x 23 columns]

# %%
# Find columns with null values
nyc.isnull()
# Out:
#         EST  Max_TemperatureF  ...  Events  WindDirDegrees
# 0     False             False  ...   False           False
# 1     False             False  ...   False           False
# 2     False             False  ...   False           False
# 3     False             False  ...   False           False
# 4     False             False  ...   False           False
# ...     ...               ...  ...     ...             ...
# 3282  False             False  ...   False           False
# 3283  False             False  ...   False           False
# 3284  False             False  ...   False           False
# 3285  False             False  ...   False           False
# 3286  False             False  ...   False           False
#
# [3287 rows x 23 columns]

# %%
# Find columns with null values
nyc.isnull().any()
# Out:
# EST                          False
# Max_TemperatureF              True
# Mean_TemperatureF             True
# Min_TemperatureF              True
# Max_Dew_PointF                True
# MeanDew_PointF                True
# Min_DewpointF                 True
# Max_Humidity                  True
# Mean_Humidity                 True
# Min_Humidity                  True
# Max_Sea_Level_PressureIn      True
# Mean_Sea_Level_PressureIn     True
# Min_Sea_Level_PressureIn      True
# Max_VisibilityMiles           True
# Mean_VisibilityMiles          True
# Min_VisibilityMiles           True
# Max_Wind_SpeedMPH             True
# Mean_Wind_SpeedMPH            True
# Max_Gust_SpeedMPH             True
# PrecipitationIn               True
# CloudCover                    True
# Events                       False
# WindDirDegrees                True
# dtype: bool

# %%
missing_df = nyc.isnull() 
nyc[missing_df.Max_TemperatureF]
# Out:
#             EST  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 2219 2012-01-29               NaN                NaN               NaN
# 2220 2012-01-30               NaN                NaN               NaN
#
#       Max_Dew_PointF  MeanDew_PointF  Min_DewpointF  Max_Humidity  \
# 2219             NaN             NaN            NaN           NaN
# 2220             NaN             NaN            NaN           NaN
#
#       Mean_Humidity  Min_Humidity       ...        Max_VisibilityMiles  \
# 2219            NaN           NaN       ...                        NaN
# 2220            NaN           NaN       ...                        NaN
#
#       Mean_VisibilityMiles  Min_VisibilityMiles  Max_Wind_SpeedMPH  \
# 2219                   NaN                  NaN                NaN
# 2220                   NaN                  NaN                NaN
#
#       Mean_Wind_SpeedMPH  Max_Gust_SpeedMPH  PrecipitationIn  CloudCover  \
# 2219                 NaN                NaN              0.0         NaN
# 2220                 NaN                NaN              NaN         NaN
#
#       Events  WindDirDegrees
# 2219                     NaN
# 2220                     NaN
#
# [2 rows x 23 columns]

# %%
nyc.Max_TemperatureF.fillna(nyc.Max_TemperatureF.mean()).iloc[2219:2222]
# Out:
# 2219    62.930898
# 2220    62.930898
# 2221    55.000000
# Name: Max_TemperatureF, dtype: float64

# %%
# The .interpolate method will do linear interpolation by default
nyc.Max_TemperatureF.interpolate().iloc[2219:2222]
# Out:
# 2219    47.666667
# 2220    51.333333
# 2221    55.000000
# Name: Max_TemperatureF, dtype: float64

# %%
#dropping rows with missing data
nyc.dropna()
# Out:
#             EST  Max_TemperatureF  Mean_TemperatureF  Min_TemperatureF  \
# 0    2006-01-01              42.0               37.0              32.0
# 1    2006-01-02              48.0               44.0              39.0
# 2    2006-01-03              40.0               37.0              33.0
# 3    2006-01-04              38.0               34.0              29.0
# 4    2006-01-05              50.0               44.0              37.0
# 5    2006-01-06              43.0               37.0              30.0
# 6    2006-01-07              35.0               30.0              25.0
# 7    2006-01-08              46.0               40.0              34.0
# 8    2006-01-09              60.0               52.0              43.0
# 9    2006-01-10              49.0               45.0              41.0
# 10   2006-01-11              52.0               47.0              42.0
# 11   2006-01-12              57.0               51.0              45.0
# 12   2006-01-13              54.0               49.0              43.0
# 13   2006-01-14              57.0               44.0              31.0
# 3275                  10.0                 10.0               12.0
# 3276                   9.0                  6.0                9.0
# 3277                   8.0                  5.0               12.0
# 3278                   3.0                  2.0               17.0
# 3279                   3.0                  1.0               12.0
# 3280                   8.0                  2.0               20.0
# 3281                  10.0                 10.0               13.0
# 3282                  10.0                 10.0               14.0
# 3283                   9.0                  2.0               15.0
# 3284                  10.0                 10.0               15.0
# 3285                  10.0                 10.0               10.0
# 3286                  10.0                 10.0               14.0
#
#       Mean_Wind_SpeedMPH  Max_Gust_SpeedMPH  PrecipitationIn  CloudCover  \
# 0                    3.0               10.0            0.000         8.0
# 1                    5.0               24.0            0.630         5.0
# 2                   15.0               41.0            1.130         8.0
# 3                    7.0               20.0            0.000         3.0
# 4                    5.0               21.0            0.050         6.0
# 5                    6.0               25.0            0.000         7.0
# 6                    7.0               23.0            0.000         2.0
# 7                    5.0               17.0            0.000         3.0
# 8                    8.0               24.0            0.000         1.0
# 9                    6.0               16.0            0.000         1.0
# 10                   4.0               21.0            0.230         7.0
# 11                   7.0               20.0            0.000         0.0
# 12                   3.0               17.0            0.000         5.0
# 13                   9.0               36.0            1.170         8.0
# 14                  13.0               39.0            0.120         5.0
# 15                   8.0               24.0            0.000         0.0
# 16                   6.0               20.0            0.160         5.0
# 17                  12.0               41.0            0.590         7.0
# 18                   8.0               23.0            0.000         0.0
# 19                   8.0               23.0            0.000         0.0
# 20                  10.0               39.0            0.000         2.0
# 21                   7.0               23.0            0.000         1.0
# 22                   4.0               17.0            0.680         7.0
# 23                   7.0               18.0            0.000         1.0
# 24                  10.0               32.0            0.000         4.0
# 25                  14.0               30.0            0.000         1.0
# 26                   8.0               22.0            0.000         0.0
# 27                   6.0               21.0            0.000         0.0
# 28                   5.0               20.0            0.140         5.0
# 29                   8.0               28.0            0.010         4.0
# ...                  ...                ...              ...         ...
# 3257                 9.0               26.0            0.080         7.0
# 3258                 8.0               26.0            0.060         7.0
# 3259                 6.0               19.0            0.000         0.0
# 3260                 6.0               21.0            0.510         6.0
# 3261                 4.0               30.0            1.220         8.0
# 3262                12.0               40.0            0.040         1.0
# 3263                12.0               29.0            0.000         6.0
# 3264                10.0               32.0            2.540         8.0
# 3265                 8.0               24.0            0.080         8.0
# 3266                 8.0               25.0            0.010         7.0
# 3267                 8.0               25.0            0.000         6.0
# 3268                 9.0               28.0            0.000         2.0
# 3269                 6.0               20.0            0.000         4.0
# 3270                 3.0               12.0            0.000         0.0
# 3271                 4.0               14.0            0.200         7.0
# 3272                 6.0               26.0            0.020         7.0
# 3273                 9.0               28.0            0.000         6.0
# 3274                 7.0               24.0            0.000         5.0
# 3275                 5.0               15.0            0.000         8.0
# 3276                 5.0               13.0            0.001         8.0
# 3277                 6.0               16.0            0.040         8.0
# 3278                 8.0               26.0            0.160         8.0
# 3279                 6.0               17.0            0.800         8.0
# 3280                10.0               32.0            0.090         5.0
# 3281                 6.0               18.0            0.000         0.0
# 3282                 4.0               25.0            0.000         0.0
# 3283                 6.0               22.0            0.100         5.0
# 3284                 5.0               25.0            0.000         0.0
# 3285                 4.0               17.0            0.000         2.0
# 3286                 6.0               21.0            0.000         2.0
#
#          Events  WindDirDegrees
# 0                         276.0
# 1          Rain            76.0
# 2          Rain            39.0
# 3                          70.0
# 4          Rain           251.0
# 5                         317.0
# 6                         267.0
# 7                         192.0
# 8                         249.0
# 9                         261.0
# 10         Rain            71.0
# 11                        246.0
# 12                        171.0
# 13         Rain           158.0
# 14     Fog-Snow           298.0
# 15                        279.0
# 16         Rain            67.0
# 17         Rain           217.0
# 18                        244.0
# 19                        233.0
# 20                        263.0
# 21                         49.0
# 22    Rain-Snow            51.0
# 23                        185.0
# 24                        266.0
# 25                        292.0
# 26                        274.0
# 27                        243.0
# 28         Rain           169.0
# 29                         64.0
# ...         ...             ...
# 3257       Rain            70.0
# 3258       Rain           276.0
# 3259                      304.0
# 3260       Rain            50.0
# 3261       Rain            36.0
# 3262       Rain            28.0
# 3263                       60.0
# 3264       Rain            36.0
# 3265  Rain-Snow           295.0
# 3266       Snow           276.0
# 3267                      303.0
# 3268                      307.0
# 3269                      306.0
# 3270                      333.0
# 3271       Rain            75.0
# 3272       Rain           294.0
# 3273                      293.0
# 3274                      307.0
# 3275                       10.0
# 3276       Snow           338.0
# 3277       Rain            59.0
# 3278       Rain            67.0
# 3279       Rain            86.0
# 3280       Rain           279.0
# 3281                      272.0
# 3282                      257.0
# 3283       Rain           264.0
# 3284                      308.0
# 3285                        5.0
# 3286                      275.0
#
# [3174 rows x 23 columns]

# %% [markdown]
# ## Dealing with NaN Assignment
# * Find the rows that have null data
# * Find the columns that have null data
# * It looks like the ``zon_winds`` has some missing values, use summary stats or plotting to determine how to fill in those values

# %%
# Rows with null data
nino.isnull().any(axis=1)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 178050    False
# 178051    False
# 178052    False
# 178053    False
# 178054    False
# 178055    False
# 178056    False
# 178057    False
# 178058    False
# 178059    False
# 178060    False
# 178061    False
# 178062    False
# 178063    False
# 178064    False
# 178065    False
# 178066    False
# 178067    False
# 178068    False
# 178069    False
# 178070    False
# 178071    False
# 178072    False
# 178073    False
# 178074    False
# 178075    False
# 178076    False
# 178077    False
# 178078    False
# 178079     True
# Length: 178080, dtype: bool

# %%
# Columns with null data
nino.isnull().any(axis=0)
# Out:
# year_month_day    False
# date              False
# latitude          False
# longitude         False
# zon_winds          True
# mer_winds          True
# humidity           True
# air_temp_          True
# s_s_temp_          True
# air_temp_F         True
# zon_winds_mph      True
# mer_winds_mph      True
# year              False
# dtype: bool

# %%
nino[nino.isnull().zon_winds].shape, nino.shape
# Out:
# ((25163, 13), (178080, 13))

# %%
nino.zon_winds.describe()
# Out:
# count    152917.000000
# mean         -3.304772
# std           3.373492
# min         -12.400000
# 25%          -5.800000
# 50%          -4.000000
# 75%          -1.400000
# max          14.300000
# Name: zon_winds, dtype: float64

# %%
nino.zon_winds.hist()

# %%
nino[nino.isnull().zon_winds] = nino.zon_winds.median()
